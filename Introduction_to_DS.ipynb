# %%
import json

# %%
# Ceated a function to load data
def load_data(filename):
    with open(filename, "r") as f:
        data = json.load(f)
    return data

# %%
data = load_data("data.json")

# %%
data
# Out:
# {'users': [{'id': 1,
#    'name': 'Neo',
#    'friends': [2, 3, 5],
#    'liked_pages': [101, 111, 112, 115]},
#   {'id': 2, 'name': 'Elena', 'friends': [1, 4, 8], 'liked_pages': [102, 103]},
#   {'id': 3,
#    'name': 'John',
#    'friends': [1, 6, 7],
#    'liked_pages': [104, 105, 110]},
#   {'id': 4, 'name': 'Aisha', 'friends': [2, 9, 10], 'liked_pages': [106, 107]},
#   {'id': 5,
#    'name': 'Dmitri',
#    'friends': [1, 11, 12],
#    'liked_pages': [108, 109, 110]},
#   {'id': 6, 'name': 'Yuki', 'friends': [3, 13, 14], 'liked_pages': [101, 115]},
#   {'id': 7, 'name': 'Chen', 'friends': [3, 15, 16], 'liked_pages': [111, 112]},
#   {'id': 8,
#    'name': 'Liam',
#    'friends': [2, 17, 18],
#    'liked_pages': [102, 113, 114]},
#   {'id': 9,
#    'name': 'Sofia',
#    'friends': [4, 19, 20],
#    'liked_pages': [103, 104]},
#   {'id': 10,
#    'name': 'Ivan',
#    'friends': [4, 11, 15],
#    'liked_pages': [105, 106]},
#   {'id': 11,
#    'name': 'Priya',
#    'friends': [5, 10, 16],
#    'liked_pages': [107, 108]},
#   {'id': 12, 'name': 'Mateo', 'friends': [5, 17], 'liked_pages': [109, 113]},
#   {'id': 13, 'name': 'Fatoumata', 'friends': [6, 18], 'liked_pages': []},
#   {'id': 14, 'name': 'Lars', 'friends': [6, 19], 'liked_pages': [110, 114]},
#   {'id': 15,
#    'name': 'Hiroshi',
#    'friends': [7, 10, 20],
#    'liked_pages': [111, 115]},
#   {'id': 16, 'name': 'Chloe', 'friends': [7, 11], 'liked_pages': [104, 108]},
#   {'id': 17, 'name': 'Olga', 'friends': [8, 12], 'liked_pages': [103, 112]},
#   {'id': 18, 'name': 'Rajesh', 'friends': [8, 13], 'liked_pages': [105, 107]},
#   {'id': 19, 'name': 'Jamal', 'friends': [9, 14], 'liked_pages': []},
#   {'id': 20, 'name': 'Emma', 'friends': [9, 15], 'liked_pages': [106, 109]}],
#  'pages': [{'id': 101, 'name': 'Python Developers'},
#   {'id': 102, 'name': 'Data Science Enthusiasts'},
#   {'id': 103, 'name': 'AI & ML Community'},
#   {'id': 104, 'name': 'Web Dev Hub'},
#   {'id': 105, 'name': 'Cloud Computing Ninjas'},
#   {'id': 106, 'name': 'DevOps Masters'},
#   {'id': 107, 'name': 'Cyber Security Experts'},
#   {'id': 108, 'name': 'Open Source Contributors'},
#   {'id': 109, 'name': 'Trap Shooting Club'},
#   {'id': 110, 'name': 'Scenic Road Trips'},
#   {'id': 111, 'name': 'MLOps Engineering'},
#   {'id': 112, 'name': 'Generative AI Innovators'},
#   {'id': 113, 'name': 'Hypertrophy & Fitness'},
#   {'id': 114, 'name': 'Ovo-Vegetarian Recipes'},
#   {'id': 115, 'name': 'LeetCode Grinders'}]}

# %%
type(data)
# Out:
# dict

# %%
#wrote a fuction to check the connections between the users

def display_users(data):
    print("Users and their connections:")
    for user in data['users']:
        print(f"ID: {user['id']}. {user['name']} is friends with: {user['friends']} and liked pages are: {user['liked_pages']}")
    print("\n Pages Information:")
    for page in data['pages']:
        print(f"{page['id']}: {page['name']}")

display_users(data)
# Out:
# Users and their connections:
# ID: 1. Neo is friends with: [2, 3, 5] and liked pages are: [101, 111, 112, 115]
# ID: 2. Elena is friends with: [1, 4, 8] and liked pages are: [102, 103]
# ID: 3. John is friends with: [1, 6, 7] and liked pages are: [104, 105, 110]
# ID: 4. Aisha is friends with: [2, 9, 10] and liked pages are: [106, 107]
# ID: 5. Dmitri is friends with: [1, 11, 12] and liked pages are: [108, 109, 110]
# ID: 6. Yuki is friends with: [3, 13, 14] and liked pages are: [101, 115]
# ID: 7. Chen is friends with: [3, 15, 16] and liked pages are: [111, 112]
# ID: 8. Liam is friends with: [2, 17, 18] and liked pages are: [102, 113, 114]
# ID: 9. Sofia is friends with: [4, 19, 20] and liked pages are: [103, 104]
# ID: 10. Ivan is friends with: [4, 11, 15] and liked pages are: [105, 106]
# ID: 11. Priya is friends with: [5, 10, 16] and liked pages are: [107, 108]
# ID: 12. Mateo is friends with: [5, 17] and liked pages are: [109, 113]
# ID: 13. Fatoumata is friends with: [6, 18] and liked pages are: []
# ID: 14. Lars is friends with: [6, 19] and liked pages are: [110, 114]
# ID: 15. Hiroshi is friends with: [7, 10, 20] and liked pages are: [111, 115]
# ID: 16. Chloe is friends with: [7, 11] and liked pages are: [104, 108]
# ID: 17. Olga is friends with: [8, 12] and liked pages are: [103, 112]
# ID: 18. Rajesh is friends with: [8, 13] and liked pages are: [105, 107]
# ID: 19. Jamal is friends with: [9, 14] and liked pages are: []
# ID: 20. Emma is friends with: [9, 15] and liked pages are: [106, 109]
#
#  Pages Information:
# 101: Python Developers
# 102: Data Science Enthusiasts
# 103: AI & ML Community
# 104: Web Dev Hub
# 105: Cloud Computing Ninjas
# 106: DevOps Masters
# 107: Cyber Security Experts
# 108: Open Source Contributors
# 109: Trap Shooting Club
# 110: Scenic Road Trips
# 111: MLOps Engineering
# 112: Generative AI Innovators
# 113: Hypertrophy & Fitness
# 114: Ovo-Vegetarian Recipes
# 115: LeetCode Grinders
