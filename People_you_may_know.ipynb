# %%
import  json

def load_data(filename):
    with open("data.json", "r") as f:
        return json.load(f)

def people_you_may_know(user_id, data):
    user_friends = {}
    for user in data["users"]:
        user_friends[user['id']] = set(user['friends'])
    if user_id not in user_friends:
        return[]

    direct_friends = user_friends[user_id]
    suggestions = {}


    for friend in direct_friends:
        for mutual  in user_friends[friend]:
            if mutual != user_id and mutual not in direct_friends:
                 # Count the mutual friends
                suggestions[mutual] = suggestions.get(mutual, 0) +1

    sorted_suggestions = sorted(suggestions.items(), key = lambda x:x[1], reverse= True)
    return [suggested_id for suggested_id, mutual_count in sorted_suggestions]
                
                
            
           


    
    
#load the Data
try:
    data = load_data('data.json')
    recc = people_you_may_know(1, data)
    print(f"Suggestions for User 1: {recc}")
except FileNotFoundError:
    print("Error: data.json not found.")
# Out:
# Suggestions for User 1: [8, 4, 6, 7, 11, 12]
